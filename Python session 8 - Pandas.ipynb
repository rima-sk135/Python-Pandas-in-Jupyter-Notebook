# %%
import pandas as pd

# %%
s = pd.Series([2.1, 1.8, 2.3, 2.0], index=["Q1", "Q2", "Q3", "Q4"])
print(s)
# Out:
# Q1    2.1
# Q2    1.8
# Q3    2.3
# Q4    2.0
# dtype: float64

# %%
df = pd.DataFrame({"Name": ["Alice", "Bob", "Charlie"], "Age":[20, 25, 30]})
print(df)
# Out:
#       Name  Age
# 0    Alice   20
# 1      Bob   25
# 2  Charlie   30

# %%
## Read and Write CSV files

# %%
df1 = pd.read_csv("....csv")
df1 = pd.to_csv("output.csv", index=False)

# %%
## Read and Write Excel files

# %%
df2 = pd.read_excel("data.xlsx")
df2 pd.to_excel("output.xlsx", index=False)
